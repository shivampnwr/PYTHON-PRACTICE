# %%
import numpy as np
import pandas as pd
import os

import kagglehub

# Download latest version
path = kagglehub.dataset_download("soumyop/synthetic-employee-performance-dataset")

# print("Path to dataset files:", path)

# List all files in the downloaded folder
files = os.listdir(path)
# print("Files found:", files)

# Locate the data file (e.g., the first .csv file) and load it
employee_csv = [f for f in files if f.endswith(".csv")][0]
file_full_path = os.path.join(path, employee_csv)

df = pd.read_csv(file_full_path)

# Save a copy directly into your current project folder
df.to_csv("employee_performance.csv", index=False)
# print("Saved successfully as employee_performance.csv")

#department-wise average performance
avg_perform = df.groupby("Department")["Performance Score"].mean()
print(avg_perform)

print("\n")
#top 10 employees based on performance score
top_10 = df.sort_values(by="Performance Score", ascending=False).head(10)
print(top_10)

print("\n")
#employees with attendance below 75%
low_attend = df[df["Attendance(%)"] < 75]
print(low_attend.sum())
# Out:
# Downloading to /home/shivampanwar/.cache/kagglehub/datasets/soumyop/synthetic-employee-performance-dataset/1.archive...
# 100%|██████████| 266k/266k [00:01<00:00, 224kB/s]
# Extracting files...
# Department
# AI & Data Science         73.473552
# Customer Support          73.209900
# Finance                   73.747667
# Human Resources           73.088524
# Information Technology    73.203594
# Marketing                 73.366694
# Operations                73.578672
# Sales                     73.544862
# Name: Performance Score, dtype: float64
#
#
#        E_ID             Name  Age              Department                Role  \
# 4803  E4804      Janhvi Modi   35        Customer Support   Support Executive
# 2470  E2471  Ikshita Scindia   24  Information Technology     DevOps Engineer
# 4779  E4780    Garima Sahani   27                 Finance          Accountant
# 4764  E4765      Saket Batra   25       AI & Data Science         ML Engineer
# 3260  E3261    Triveni Gupta   50  Information Technology   Software Engineer
# 1430  E1431   Paritosh Rathi   34                 Finance   Financial Analyst
# 1738  E1739    Atishay Kamat   54              Operations  Operations Manager
# 2263  E2264  Surendra Sharma   43                 Finance   Finance Executive
# 4134  E4135    Himani Parmar   45         Human Resources        HR Executive
# 2760  E2761     Kumkum Rathi   43       AI & Data Science      Data Scientist
#
#      Employment Type Contract Duration Band  Exp Yrs  Tenure Yrs  ...  \
# 4803       Full-Time         Permanent   B3      5.3         3.8  ...
# 2470       Part-Time          6 Months   B1      0.7         0.0  ...
# 4779       Full-Time         Permanent   B2      4.3         2.5  ...
# 4764       Full-Time         Permanent   B2      2.1         1.2  ...
# 3260       Full-Time         Permanent   B5     21.2        14.8  ...
# 1430       Full-Time         Permanent   B4     11.9         7.2  ...
# 1738       Full-Time         Permanent   B5     18.0         3.3  ...
# 2263       Full-Time         Permanent   B4     11.6        10.0  ...
# 4134       Full-Time         Permanent   B5     17.5         4.3  ...
# 2760       Full-Time         Permanent   B4     12.6         7.5  ...
#
#       Teamwork Score  Leadership Score  Client Feedback  Communication  \
# 4803           88.99             59.86            86.08          89.62
# 2470           83.22             61.00            86.57          76.82
# 4779           89.61             75.36            92.80          91.93
# 4764           74.72             55.36            88.56          90.61
# 3260           81.72             89.17            91.84          90.17
# 1430           90.89             80.38            84.72          90.56
# 1738           75.59             87.21            86.25          89.83
# 2263           81.07             77.60            86.88          74.73
# 4134           82.60             84.94            86.18          81.85
# 2760           87.76             83.63            87.83          77.83
#
#       Overtime  Training Hours  Training Completion(%)  Performance Score  \
# 4803       0.0              50                   94.73              90.44
# 2470       0.0              20                   64.09              90.06
# 4779       1.1              20                   70.21              89.46
# 4764       0.0              30                   79.82              88.96
# 3260       0.0              25                   72.11              88.55
# 1430       6.5              25                   76.77              88.44
# 1738       0.8              40                   88.92              88.23
# 2263       7.7              40                   81.40              88.20
# 4134       0.0              25                   69.79              88.15
# 2760       2.7              15                   66.31              88.10
#
#       Performance Category  Recommendation
# 4803             Excellent       Incentive
# 2470             Excellent       Incentive
# 4779             Excellent       Incentive
# 4764             Excellent       Incentive
# 3260             Excellent       Incentive
# 1430             Excellent       Incentive
# 1738             Excellent       Promotion
# 2263             Excellent       Incentive
# 4134             Excellent       Promotion
# 2760             Excellent       Promotion
#
# [10 rows x 28 columns]
#
#
# E_ID                        E0013E0031E0086E0115E0121E0130E0131E0195E0223E...
# Name                        Drishti PrajapatiMitali JadhavLeela TiwariMans...
# Age                                                                     13927
# Department                  Customer SupportInformation TechnologyInformat...
# Role                        Support AnalystSoftware EngineerDevOps Enginee...
# Employment Type             Full-TimeFull-TimeFull-TimeFull-TimePart-TimeF...
# Contract Duration           PermanentPermanentPermanentPermanent12 MonthsP...
# Band                        B2B4B2B5B5B5B4B5B4B2B4B5B1B4B5B2B4B2B2B3B5B4B4...
# Exp Yrs                                                                4153.2
# Tenure Yrs                                                             2059.2
# Attendance(%)                                                         23780.5
# Leave                                                                    5827
# Tasks Assigned                                                          10617
# Tasks Completed                                                          6325
# Tasks Completion Rate(%)                                             20230.15
# Task Quality Score                                                   22056.72
# Goal Achievement(%)                                                  21991.82
# Manager Feedback                                                     23152.85
# Teamwork Score                                                       24573.54
# Leadership Score                                                     22611.32
# Client Feedback                                                      22979.64
# Communication                                                        24218.47
# Overtime                                                               2185.4
# Training Hours                                                           7675
# Training Completion(%)                                               23735.68
# Performance Score                                                     22627.3
# Performance Category        AverageAverageAverageAverageAverageAverageAver...
# Recommendation              PIPPIPPIPPIPPIPPIPPIPPIPPIPPIPTrainingPIPPIPPI...
# dtype: object

# %%
#visualization
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(3,1, figsize = (18,12))
fig.suptitle("Employee Performance Analytics System", fontweight = "bold", fontsize = 24, color = "crimson")

#performance comparision chart (deptartment wise)
dept_score = df.groupby("Department")["Performance Score"].sum()
axes[1].bar(dept_score.index , dept_score.values, alpha = 0.85 , color = "#AE97F2")
axes[1].set_title("Department Performance")
axes[1].set_xlable = ("Department")
axes[1].set_ylable = ("Performance Score")
axes[1].grid(True, linestyle = "--")

#Department distribution
dept_size = df.groupby("Department")["E_ID"].count()
axes[0].pie(
    dept_size,
        labels=dept_size,
        autopct='%1.1f%%',
        startangle=140,
        colors=sns.color_palette('Set3')
)
axes[0].set_title("Department Distribution")
print(dept_size)


#Attendance trend
sort_attend = df.groupby("Department")["Attendance(%)"].mean().sort_values()
axes[2].plot(
    sort_attend.index,
    sort_attend.values,
    marker = "o",
    markeredgecolor = 'black',
    color = "#A31818"
)
axes[2].set_title("Attendance Trend Analyser")
axes[2].set_xlable = ("Department")
axes[2].set_ylable = ("Attendance(%)")
axes[2].grid(True)


plt.tight_layout()
plt.show()
# Out:
# Department
# AI & Data Science         808
# Customer Support          502
# Finance                   480
# Human Resources           515
# Information Technology    871
# Marketing                 484
# Operations                723
# Sales                     617
# Name: E_ID, dtype: int64
